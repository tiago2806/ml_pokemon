# %% [markdown]
# ### **Data Pre Processing**

# %%
import pandas as pd

# %%
dataset = pd.read_csv('Pokemon.csv')

# %%
dataset
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# We first will check if there are NaN

# %%
dataset.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# We saw that there are 386 missing values in Type 2 columns which is completely normal because we know many pokemons dont have two types

# %%
dataset['Type 2'] = dataset['Type 2'].fillna('None')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dataset['Type 2'] = dataset['Type 2'].fillna('None')
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# ### **Duplicate Records**

# %% [markdown]
# tambem nao ha

# %%
dup = dataset.duplicated()
dup[dup == True]
# Out:
# Series([], dtype: bool)

# %% [markdown]
# ### **Check Data Types**

# %%
dataset.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object
